# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
df_kadaster = pd.read_csv('amsterdamzuid-klein.csv', index_col=False) 
# Preview the first 5 lines of the loaded data 
df_kadaster.columns =['id','perceelid', 'perceeltype', 'huisnr', 'huisnr_bag_letter','huisnr_bag_toevoeging','bag_nummeraanduidingid','bag_adresseerbaarobjectid','lat','lon','rdx','rdy','oppervlakte','gebruiksdoel','reeksid']
df_kadaster = df_kadaster.drop(['id'],axis=1)
df_kadaster = df_kadaster.set_index('perceelid')
df_kadaster.head()
# Out:
#                perceeltype  huisnr huisnr_bag_letter huisnr_bag_toevoeging  \
# perceelid
# 307477     verblijfsobject      93               NaN                     1
# 307478     verblijfsobject      93               NaN                     2
# 307479     verblijfsobject      93               NaN                     3
# 307480     verblijfsobject      93               NaN                     H
# 307481     verblijfsobject      95               NaN                     1
#
#            bag_nummeraanduidingid  bag_adresseerbaarobjectid        lat  \
# perceelid
# 307477               3.632000e+14               3.630100e+14  52.350966
# 307478               3.632000e+14               3.630100e+14  52.350966
# 307479               3.632000e+14               3.630100e+14  52.350966
# 307480               3.632000e+14               3.630100e+14  52.350966
# 307481               3.632000e+14               3.630100e+14  52.350985
#
#                 lon       rdx       rdy  oppervlakte gebruiksdoel  reeksid
# perceelid
# 307477     4.897374  121626.0  484897.0           49  woonfunctie    14548
# 307478     4.897374  121626.0  484897.0           53  woonfunctie    14548
# 307479     4.897374  121626.0  484897.0           53  woonfunctie    14548
# 307480     4.897374  121626.0  484897.0           53  woonfunctie    14548
# 307481     4.897476  121633.0  484899.0           51  woonfunctie    14548

# %%
df_kadaster
# Out:
#                perceeltype  huisnr huisnr_bag_letter huisnr_bag_toevoeging  \
# perceelid
# 307477     verblijfsobject      93               NaN                     1
# 307478     verblijfsobject      93               NaN                     2
# 307479     verblijfsobject      93               NaN                     3
# 307480     verblijfsobject      93               NaN                     H
# 307481     verblijfsobject      95               NaN                     1
# ...                    ...     ...               ...                   ...
# 342098     verblijfsobject      58               NaN                     3
# 342099     verblijfsobject      58               NaN                     H
# 8544776    verblijfsobject      50               NaN                     H
# 8544777    verblijfsobject      48               NaN                     H
# 8544778    verblijfsobject       8               NaN                   NaN
#
#            bag_nummeraanduidingid  bag_adresseerbaarobjectid        lat  \
# perceelid
# 307477               3.632000e+14               3.630100e+14  52.350966
# 307478               3.632000e+14               3.630100e+14  52.350966
# 307479               3.632000e+14               3.630100e+14  52.350966
# 307480               3.632000e+14               3.630100e+14  52.350966
# 307481               3.632000e+14               3.630100e+14  52.350985
# ...                           ...                        ...        ...
# 342098               3.632000e+14               3.630100e+14  52.346611
# 342099               3.632000e+14               3.630100e+14  52.346611
# 8544776              3.632000e+14               3.630100e+14  52.346905
# 8544777              3.632000e+14               3.630100e+14  52.346974
# 8544778              3.632000e+14               3.630100e+14  52.346974
#
#                 lon         rdx         rdy  oppervlakte  \
# perceelid
# 307477     4.897374  121626.000  484897.000           49
# 307478     4.897374  121626.000  484897.000           53
# 307479     4.897374  121626.000  484897.000           53
# 307480     4.897374  121626.000  484897.000           53
# 307481     4.897476  121633.000  484899.000           51
# ...             ...         ...         ...          ...
# 342098     4.904833  122131.000  484409.000           57
# 342099     4.904833  122131.000  484409.000           95
# 8544776    4.904709  122122.791  484441.732          104
# 8544777    4.904698  122122.106  484449.436         1888
# 8544778    4.904698  122122.106  484449.436         1888
#
#                         gebruiksdoel  reeksid
# perceelid
# 307477                   woonfunctie    14548
# 307478                   woonfunctie    14548
# 307479                   woonfunctie    14548
# 307480                   woonfunctie    14548
# 307481                   woonfunctie    14548
# ...                              ...      ...
# 342098                   woonfunctie    16302
# 342099     woonfunctie,winkelfunctie    16302
# 8544776                winkelfunctie    16302
# 8544777                winkelfunctie    16302
# 8544778                winkelfunctie    16281
#
# [3425 rows x 13 columns]

# %%
straal = 20

df = df_kadaster.copy()

for i, j in df.iterrows():
    rdx_punt = j[8]
    rdy_punt = j[9]

    rdx_min = rdx_punt - straal
    rdx_max = rdx_punt + straal
    rdy_min = rdy_punt - straal 
    rdy_max = rdy_punt + straal

    ##jel = ((df['rdx'] > rdx_min) & 
    ##            (df['rdx'] < rdx_max) & 
    ##            (df['rdy'] > rdy_min) &
     ##           (df['rdy'] < rdy_max)).sum()

    rslt_df = df[(df['rdx'] > rdx_min) &
               (df['rdx'] < rdx_max) &
              (df['rdy'] > rdy_min) &
              (df['rdy'] < rdy_max)]

    #print("Lat/lon: " + str(rdx_punt) + " / " + str(rdy_punt) + " == " + str(jel))
    jel = len(rslt_df.index)
    df.at[i,'Buren'] = jel
df
# Out:
#                perceeltype  huisnr huisnr_bag_letter huisnr_bag_toevoeging  \
# perceelid
# 307477     verblijfsobject    93.0               NaN                     1
# 307478     verblijfsobject    93.0               NaN                     2
# 307479     verblijfsobject    93.0               NaN                     3
# 307480     verblijfsobject    93.0               NaN                     H
# 307481     verblijfsobject    95.0               NaN                     1
# ...                    ...     ...               ...                   ...
# 342099     verblijfsobject    58.0               NaN                     H
# 8544776    verblijfsobject    50.0               NaN                     H
# 8544777    verblijfsobject    48.0               NaN                     H
# 8544778    verblijfsobject     8.0               NaN                   NaN
# Buren                  NaN     NaN               NaN                   NaN
#
#            bag_nummeraanduidingid  bag_adresseerbaarobjectid        lat  \
# perceelid
# 307477               3.632000e+14               3.630100e+14  52.350966
# 307478               3.632000e+14               3.630100e+14  52.350966
# 307479               3.632000e+14               3.630100e+14  52.350966
# 307480               3.632000e+14               3.630100e+14  52.350966
# 307481               3.632000e+14               3.630100e+14  52.350985
# ...                           ...                        ...        ...
# 342099               3.632000e+14               3.630100e+14  52.346611
# 8544776              3.632000e+14               3.630100e+14  52.346905
# 8544777              3.632000e+14               3.630100e+14  52.346974
# 8544778              3.632000e+14               3.630100e+14  52.346974
# Buren                         NaN                        NaN        NaN
#
#                 lon         rdx         rdy  ...  342093 342094  342095  \
# perceelid                                    ...
# 307477     4.897374  121626.000  484897.000  ...     NaN    NaN     NaN
# 307478     4.897374  121626.000  484897.000  ...     NaN    NaN     NaN
# 307479     4.897374  121626.000  484897.000  ...     NaN    NaN     NaN
# 307480     4.897374  121626.000  484897.000  ...     NaN    NaN     NaN
# 307481     4.897476  121633.000  484899.000  ...     NaN    NaN     NaN
# ...             ...         ...         ...  ...     ...    ...     ...
# 342099     4.904833  122131.000  484409.000  ...     NaN    NaN     NaN
# 8544776    4.904709  122122.791  484441.732  ...     NaN    NaN     NaN
# 8544777    4.904698  122122.106  484449.436  ...     NaN    NaN     NaN
# 8544778    4.904698  122122.106  484449.436  ...     NaN    NaN     NaN
# Buren           NaN         NaN         NaN  ...    33.0   33.0    33.0
#
#            342096  342097  342098  342099  8544776  8544777  8544778
# perceelid
# 307477        NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 307478        NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 307479        NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 307480        NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 307481        NaN     NaN     NaN     NaN      NaN      NaN      NaN
# ...           ...     ...     ...     ...      ...      ...      ...
# 342099        NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 8544776       NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 8544777       NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 8544778       NaN     NaN     NaN     NaN      NaN      NaN      NaN
# Buren        33.0    29.0    29.0    29.0     24.0     23.0     23.0
#
# [3426 rows x 3438 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tv/408nk24n42j7rhs01s6ptxc00000gn/T/ipykernel_84068/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df_dummy = pd.read_csv('dummy_def.csv',delimiter=';') 

df_dummy.tail()
# Out:
#                                                 object_id  incident  \
# 188803  82dc2820e82c5b79e6876209e83c802ac36fbf8d72b5f1...         0
# 188804  91d8b28b71969b077b037223083a833f95d2f0a0e3c75e...         0
# 188805  1f44551055c236017d222f45189196ba7ab2bd2a0c38f7...         0
# 188806  f7897f3ba448a860eb0ee2909324d5dd5e20b1e863bd03...         0
# 188807  f7897f3ba448a860eb0ee2909324d5dd5e20b1e863bd03...         0
#
#         nr_of_accomodations_in_building  \
# 188803                                4
# 188804                                4
# 188805                                4
# 188806                               26
# 188807                               22
#
#         nr_of_residential_accomodations_in_building  floorsize_accomodation  \
# 188803                                            0                     415
# 188804                                            1                    1507
# 188805                                            3                   22194
# 188806                                           25                      36
# 188807                                           10                      25
#
#         construction_year    timeline                 function  \
# 188803               1836  31/12/9999  Kantoor|Opslag/magazijn
# 188804               1615  31/12/9999                  Kantoor
# 188805               1618  31/12/9999          Overige ruimten
# 188806               1712  09/08/2013                   Woning
# 188807               1712  31/12/9999                   Woning
#
#                 situation ownership  is_monument      neighborhood  \
# 188803  Vrijstaand gebouw      Huur            1  Van der Pekbuurt
# 188804       Tussengebouw  Eigendom            0  Leliegracht e.o.
# 188805  Vrijstaand gebouw      Huur            0  Nieuwe Kerk e.o.
# 188806       Tussengebouw      Huur            0      Weesperbuurt
# 188807       Tussengebouw      Huur            0      Weesperbuurt
#
#         nr_of_inspections_within_timeline  nr_of_inspections_with_observation  \
# 188803                                  6                                   1
# 188804                                  1                                   0
# 188805                                  3                                   2
# 188806                                  1                                   0
# 188807                                  4                                   2
#
#         nr_of_inspections_without_observation
# 188803                                      5
# 188804                                      1
# 188805                                      1
# 188806                                      1
# 188807                                      2
