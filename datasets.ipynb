# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
df_kadaster = pd.read_csv('amsterdamzuid.csv', index_col=False) 
# Preview the first 5 lines of the loaded data 
df_kadaster.columns =['id','perceelid', 'perceeltype', 'huisnr', 'huisnr_bag_letter','huisnr_bag_toevoeging','bag_nummeraanduidingid','bag_adresseerbaarobjectid','lat','lon','rdx','rdy','oppervlakte','gebruiksdoel','reeksid']
df_kadaster = df_kadaster.drop(['id'],axis=1)
df_kadaster = df_kadaster.set_index('perceelid')
df_kadaster.head()
# Out:
# /Users/jellevanderschoot/.pyenv/versions/3.9.4/envs/venv_python_dsp/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#                perceeltype  huisnr huisnr_bag_letter huisnr_bag_toevoeging  \
# perceelid
# 2          verblijfsobject     105               NaN                     2
# 3          verblijfsobject     105               NaN                     3
# 4          verblijfsobject     105               NaN                     H
# 5          verblijfsobject     106               NaN                     1
# 6          verblijfsobject     106               NaN                     2
#
#            bag_nummeraanduidingid  bag_adresseerbaarobjectid        lat  \
# perceelid
# 2                    3.632000e+14               3.630100e+14  52.377782
# ...

# %%
df_kadaster
# Out:
#                perceeltype  huisnr huisnr_bag_letter huisnr_bag_toevoeging  \
# perceelid
# 2          verblijfsobject     105               NaN                     2
# 3          verblijfsobject     105               NaN                     3
# 4          verblijfsobject     105               NaN                     H
# 5          verblijfsobject     106               NaN                     1
# 6          verblijfsobject     106               NaN                     2
# ...                    ...     ...               ...                   ...
# 8616908        standplaats     128               NaN                   NaN
# 8616909        standplaats     132               NaN                   NaN
# 8616910        standplaats     136               NaN                   NaN
# 8616911        standplaats     138               NaN                   NaN
# 8616912        standplaats     142               NaN                   NaN
#
# ...

# %%
straal = 20

df = df_kadaster.copy()

for i, j in df.iterrows():
    rdx_punt = j[8]
    rdy_punt = j[9]

    rdx_min = rdx_punt - straal
    rdx_max = rdx_punt + straal
    rdy_min = rdy_punt - straal 
    rdy_max = rdy_punt + straal

    ##jel = ((df['rdx'] > rdx_min) & 
    ##            (df['rdx'] < rdx_max) & 
    ##            (df['rdy'] > rdy_min) &
     ##           (df['rdy'] < rdy_max)).sum()

    rslt_df = df[(df['rdx'] > rdx_min) &
               (df['rdx'] < rdx_max) &
              (df['rdy'] > rdy_min) &
              (df['rdy'] < rdy_max)]

    #print("Lat/lon: " + str(rdx_punt) + " / " + str(rdy_punt) + " == " + str(jel))
    jel = len(rslt_df.index)
    df.at['Buren', i] = jel
df
df.to_csv('buren.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/tv/408nk24n42j7rhs01s6ptxc00000gn/T/ipykernel_84068/4035134992.py in <module>
#      17      ##           (df['rdy'] < rdy_max)).sum()
#      18
# ---> 19     rslt_df = df[(df['rdx'] > rdx_min) &
#      20                (df['rdx'] < rdx_max) &
#      21               (df['rdy'] > rdy_min) &
#
# ~/.pyenv/versions/3.9.4/envs/venv_python_dsp/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# ~/.pyenv/versions/3.9.4/envs/venv_python_dsp/lib/python3.9/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tv/408nk24n42j7rhs01s6ptxc00000gn/T/ipykernel_84068/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df_dummy = pd.read_csv('dummy_def.csv',delimiter=';') 

df_dummy.tail()
# Out:
#                                                 object_id  incident  \
# 188803  82dc2820e82c5b79e6876209e83c802ac36fbf8d72b5f1...         0
# 188804  91d8b28b71969b077b037223083a833f95d2f0a0e3c75e...         0
# 188805  1f44551055c236017d222f45189196ba7ab2bd2a0c38f7...         0
# 188806  f7897f3ba448a860eb0ee2909324d5dd5e20b1e863bd03...         0
# 188807  f7897f3ba448a860eb0ee2909324d5dd5e20b1e863bd03...         0
#
#         nr_of_accomodations_in_building  \
# 188803                                4
# 188804                                4
# 188805                                4
# 188806                               26
# 188807                               22
#
#         nr_of_residential_accomodations_in_building  floorsize_accomodation  \
# 188803                                            0                     415
# 188804                                            1                    1507
# 188805                                            3                   22194
# ...
