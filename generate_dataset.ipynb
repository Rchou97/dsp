# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv('bagadres-woning.csv',delimiter=';') 
# Preview the first 5 lines of the loaded data 
#data.columns =['perceelid', 'perceeltype', 'huisnr', 'huisnr_bag_letter','huisnr_bag_toevoeging','bag_nummeraanduidingid','bag_adresseerbaarobjectid','lat','lon','rdx','rdy','oppervlakte','gebruiksdoel','reeksid'] 
data.head()
# Out:
# /Users/jellevanderschoot/.pyenv/versions/3.9.4/envs/venv_python_dsp/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (1,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   openbareruimtenaam verkorteopenbareruimtenaam  openbareruimte_id  \
# 0     De Ruijterkade                        NaN    363300000006091
# 1     De Ruijterkade                        NaN    363300000006091
# 2     De Ruijterkade                        NaN    363300000006091
# 3     De Ruijterkade                        NaN    363300000006091
# 4     De Ruijterkade                        NaN    363300000006091
#
#    huisnummer huisletter huisnummertoevoeging postcode  nummeraanduiding_id  \
# 0         105        NaN                    1   1011AB      363200000081086
# 1         105        NaN                    2   1011AB      363200000081087
# ...

# %%
data.drop(['verkorteopenbareruimtenaam','openbareruimte_id','nummeraanduiding_id','woonplaatscode','gemeente','provincienaam','provinciecode','uniq_key','pchnhlht','pchnhlht_uniek','pchn_uniek','rangorde_pchn'], axis=1, inplace=True)
data
# Out:
#         openbareruimtenaam  huisnummer huisletter huisnummertoevoeging  \
# 0           De Ruijterkade         105        NaN                    1
# 1           De Ruijterkade         105        NaN                    2
# 2           De Ruijterkade         105        NaN                    3
# 3           De Ruijterkade         105        NaN                    H
# 4           De Ruijterkade         106        NaN                    1
# ...                    ...         ...        ...                  ...
# 9523522    von Suppéstraat           7        NaN                 G022
# 9523523    von Suppéstraat           7        NaN                 G023
# 9523524    von Suppéstraat           7        NaN                 G024
# 9523525    von Suppéstraat           7        NaN                 G025
# 9523526    von Suppéstraat           7        NaN                 G026
#
#         postcode         buurtnaam   buurtcode            wijknaam  wijkcode  \
# ...

# %%
rdx_min = 119623
rdx_max = 121646
rdy_min = 483648
rdy_max = 485107

df_kadam = data[(data['x'] > rdx_min) & 
               (data['x'] < rdx_max) &
              (data['y'] > rdy_min) &
              (data['y'] < rdy_max)]

df_kadam.to_csv('final-amsterdamzuid.csv')

# %%
df_kadam
# Out:
#             openbareruimtenaam  huisnummer huisletter huisnummertoevoeging  \
# 64596        Pieter Baststraat          24        NaN                    5
# 73947        Groenendaalstraat          34        NaN                    3
# 234651              Sloterkade          54        NaN                  NaN
# 234652              Sloterkade          55        NaN                  NaN
# 234653              Sloterkade          56        NaN                  NaN
# ...                        ...         ...        ...                  ...
# 9513314  Willem Royaardsstraat          18          G                  NaN
# 9518655              Zuidplein           5        NaN                  NaN
# 9518656              Zuidplein          10        NaN                  NaN
# 9518657              Zuidplein          26        NaN                  NaN
# 9518658              Zuidplein          42        NaN                  NaN
#
# ...
